# %%
import numpy as np
import pandas as pd
import sklearn

from sklearn.pipeline import make_pipeline

def rmse(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)

    distance = predict - actual

    square_distance = distance ** 2

    mean_square_distance = square_distance.mean()

    score = np.sqrt(mean_square_distance)

    return score

# %%
# read data files
data = pd.read_csv('i.csv', header = None, float_precision='high', sep = ';', dtype = np.float64)
target = pd.read_csv('o.csv', header = None, float_precision='high', sep = ';', dtype = np.float64)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# set some random
np.random.seed(76213)

# make train data with normalize
scaler = StandardScaler()
scaler.fit(data) 
scaled_df = scaler.transform(data)

# make train data
X_train, X_test, y_train, y_test = train_test_split(scaled_df, target, test_size=0.33, random_state=42)
y_train = np.ravel(y_train);

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# SGD regressor (best: 0.00138)
model = SGDRegressor(tol=0.0001, learning_rate='adaptive')
model.fit(X_train, y_train)
# Out:
# SGDRegressor(learning_rate='adaptive', tol=0.0001)

# %%
from sklearn.metrics import mean_squared_error


train_mse = mean_squared_error(y_train, model.predict(X_train))
test_mse = mean_squared_error(y_test, model.predict(X_test))
print("Train MSE: {}".format(train_mse))
print("Test MSE: {}".format(test_mse))
# Out:
# Train MSE: 1.956989341467918e-06
# Test MSE: 1.914626606191334e-06

# %%
# calc RMSE
mse = mean_squared_error(y_train, model.predict(X_train), squared=0) 
print("RMSE: {}".format((mse)))
# Out:
# RMSE: 0.001398924351588719

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve 
from sklearn.metrics import make_scorer 

# %matplotlib inline

# Источник: http://scikit-learn.org/0.15/auto_examples/plot_learning_curve.html
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
 
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Train примеры")
    plt.ylabel("Оценка")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, 
        scoring=make_scorer(rmse, greater_is_better = False))
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Train score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="C-V score")

    plt.legend(loc="best")
    return plt

# %%
 plot_learning_curve(model, 
                     "Кривая обучения", 
                     X_train, 
                     np.ravel(y_train));

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {"eta0": [  .0005, .0009, .0001, .0003, .001, .003, .01, .03, 1, 3]} 
linear_regression_model = SGDRegressor(tol=.0001) 
n_iter_search = 10
random_search = RandomizedSearchCV(linear_regression_model, 
                                   param_distributions=param_dist, 
                                   n_iter=n_iter_search, 
                                   cv=3,
                                   n_jobs=4,
                                   scoring=make_scorer(rmse, greater_is_better = False))
print("iter:{}".format(n_iter_search))

# Поиск оптимальных параметров
random_search.fit(X_train, y_train)
# Out:
# iter:10
# RandomizedSearchCV(cv=3, estimator=SGDRegressor(tol=0.0001), n_jobs=4,
#                    param_distributions={'eta0': [0.0005, 0.0009, 0.0001, 0.0003,
#                                                  0.001, 0.003, 0.01, 0.03, 1,
#                                                  3]},
#                    scoring=make_scorer(rmse, greater_is_better=False))

# %%
print("Лучшие параметры: {}".format(random_search.best_params_)) 
print("Лучшая оценка RMSE: {}".format(random_search.best_score_))
# Out:
# Лучшие параметры: {'eta0': 0.03}
# Лучшая оценка RMSE: -0.0014209141424261537

# %%
sorted(list(zip(data.columns, model.coef_)), 
       key=lambda x: abs(x[1]))
# Out:
# [(11, 6.86082585518748e-07),
#  (6, 9.907324085533782e-06),
#  (10, -1.050007505098033e-05),
#  (9, -3.0750879434658447e-05),
#  (22, -0.00014813295642252704),
#  (16, -0.00016095081396571458),
#  (18, -0.00018246197176793546),
#  (17, 0.00019020663118580789),
#  (12, -0.0002031333512843966),
#  (23, 0.00020451276775527877),
#  (7, -0.0004126757859139922),
#  (5, -0.0004491199060943912),
#  (8, 0.00045742398346768743),
#  (0, 0.0007219420606700749),
#  (4, 0.0007834727416911711),
#  (21, 0.0014087689747656023),
#  (3, 0.002562911046012672),
#  (15, 0.002711203529492479),
#  (20, 0.005119903931577506),
#  (19, -0.0052792232383428355),
#  (14, 0.008691443585437721),
#  (13, -0.008993174046246019),
#  (1, -0.009474493029926707),
#  (2, 0.010808659832596596)]
